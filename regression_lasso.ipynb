# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/regression_lasso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You already know:
#
# Ridge = controls overfitting
#
# Ridge keeps all features
#
# Lasso does something EXTRA:
#
# Lasso removes useless features completely.
#
# That’s the key difference.

# %% [markdown]
# REAL-LIFE ANALOGY (THIS WILL STICK)
# Team Selection 🏏
#
# Polynomial model → selects everyone (overfit)
#
# Ridge → keeps everyone but controls behavior
#
# Lasso → removes lazy players entirely
#
# 👉 Some coefficients become exactly zero.

# %%
# ============================
# Lasso Regression (One Cell)
# ============================

# 1. Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 2. Create dataset
data = {
    "Experience": [1, 2, 3, 4, 5, 6],
    "Salary": [3, 5, 9, 15, 23, 35]
}

df = pd.DataFrame(data)
print("Dataset:")
print(df)

# 3. Feature & target
X = df[["Experience"]]
y = df["Salary"]

# 4. Polynomial features
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

# 5. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, y, test_size=0.2, random_state=42
)

# 6. Train Lasso Regression
model = Lasso(alpha=0.1)  # higher alpha = more features removed
model.fit(X_train, y_train)

# 7. Predict
y_pred = model.predict(X_test)

# 8. Evaluate
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R2  :", r2)

# 9. Model parameters
print("\nCoefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Dataset:
#    Experience  Salary
# 0           1       3
# 1           2       5
# 2           3       9
# 3           4      15
# 4           5      23
# 5           6      35
#
# Model Evaluation:
# MAE : 1.7381418092909575
# MSE : 3.214607875371395
# RMSE: 1.7929327581845882
# R2  : -2.214607875371395
#
# Coefficients: [-0.         0.9599022]
# Intercept: -0.137897310513452
