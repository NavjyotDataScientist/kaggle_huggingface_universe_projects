# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/4_0_distancebased_knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KNN REGRESSION
#
# - Now KNN says:
#
# ❝ I will NOT learn anything in advance.
# I will decide only when a new point arrives. ❞
#
# That’s why it’s called:
#
# Lazy learning
#
# Instance-based learning
#
# Distance-based learning

# %%
# “KNN Regression predicts values by averaging the outputs of the nearest data points based on distance.”

# %%
# ==================================
# KNN Regression (Distance-Based)
# ==================================

# 1. Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 2. Create dataset
data = {
    "Experience": [1, 2, 3, 4, 5, 6, 7],
    "Salary": [3, 5, 9, 15, 23, 35, 50]
}

df = pd.DataFrame(data)
print("Dataset:")
print(df)

# 3. Feature & target
X = df[["Experience"]]
y = df["Salary"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 5. Scale features (IMPORTANT for KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 6. Train KNN model
model = KNeighborsRegressor(
    n_neighbors=3,   # K = 3 neighbors
    metric='euclidean'
)
model.fit(X_train_scaled, y_train)

# 7. Predict
y_pred = model.predict(X_test_scaled)

# 8. Evaluate
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R2  :", r2)
# Out:
# Dataset:
#    Experience  Salary
# 0           1       3
# 1           2       5
# 2           3       9
# 3           4      15
# 4           5      23
# 5           6      35
# 6           7      50
#
# Model Evaluation:
# MAE : 9.666666666666666
# MSE : 102.1111111111111
# RMSE: 10.105004260816079
# R2  : 0.5233402489626556

# %%
# Please Note : Make sure you learn all the basic concept first otherwise while doing an project you will never understand.
