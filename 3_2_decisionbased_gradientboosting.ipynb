# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/3_2_decisionbased_gradientboosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gradient Boosting Regression
#
# This is not optional and not random.
#
# Why now?
#
# Random Forest = trees learn independently
#
# Gradient Boosting = trees learn from mistakes
#
# This completes your understanding of ensembles.

# %%
# ==================================
# Gradient Boosting Regression
# ==================================

# 1. Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 2. Dataset
data = {
    "Experience": [1, 2, 3, 4, 5, 6, 7, 8],
    "Salary": [3, 5, 9, 15, 23, 35, 50, 70]
}

df = pd.DataFrame(data)
print("Dataset:")
print(df)

# 3. Feature & target
X = df[["Experience"]]
y = df["Salary"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# 5. Train model
model = GradientBoostingRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)
model.fit(X_train, y_train)

# 6. Predict
y_pred = model.predict(X_test)

# 7. Evaluate
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R2  :", r2)
# Out:
# Dataset:
#    Experience  Salary
# 0           1       3
# 1           2       5
# 2           3       9
# 3           4      15
# 4           5      23
# 5           6      35
# 6           7      50
# 7           8      70
#
# Model Evaluation:
# MAE : 6.999592725217057
# MSE : 73.99695452935109
# RMSE: 8.602148250835432
# R2  : 0.6711246465362174

# %% [markdown]
# 🧭 WHERE YOU ARE NOW
#
# You now understand:
#
# Bagging (Random Forest)
#
# Boosting (Gradient Boosting)
#
# That’s ensemble mastery.
