# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/binary_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Before We start you can always use any tools for getting help however, (Ask yourself are you understanding that code or concept) Lock it and move.

# %% [markdown]
# 1. Supervised Learning
#
# Classification
#
# Binary Classification: Predicting one of two classes

# %% [markdown]
# ✅ Supervised Learning → Classification → Binary Classification
# 📌 Project Title
#
# Binary Classification: Spam Email Detection
#
# 1️⃣ What is Binary Classification? (Very simple explanation)
#
# Binary Classification means:
#
# Predicting one of two possible outcomes.
#
# Examples:
#
# Spam ❌ or Not Spam ✅
#
# Yes ❌ or No ✅
#
# Disease ❌ or No Disease ✅
#
# 👉 Only two classes.

# %%
# 1. Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# 2. Create dataset
data = {
    "text": [
        "Win money now",
        "Meeting at 10",
        "Free gift offer",
        "Project update",
        "Claim your prize",
        "Team lunch tomorrow"
    ],
    "label": [1, 0, 1, 0, 1, 0]
}

df = pd.DataFrame(data)

# 3. Convert text to numerical data
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df["text"])
y = df["label"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 5. Train model (Binary Classifier)
model = LogisticRegression()
model.fit(X_train, y_train)

# 6. Predictions
y_pred = model.predict(X_test)

# 7. Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# Observation:
#
# - So what we have learned here first, we dont need huge data only small dataset to understand concept.
# - once you know how to swim in lakes then rest you know very well.
# - so why we have used logistic regression, because its baseline model and what about accuracy and other metrics.
# - Listen carefully the idea the logic the rest see how it goes -- acuracy doenst matter what matter is just learning the concept.
# - If you want the accuracy lets I know we have few scientist who always think about 100 percent acuracscy so for that listen again for that it will require dataset huge, second different models too as the complexity grows the tools and idea will also grow parallely.
# - so at the first dont make mess. keep it simple for understanding then jump in ocean.
# -----------Happy with Nav--------
