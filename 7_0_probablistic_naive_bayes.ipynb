# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/7_0_probablistic_naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WHY Probabilistic Models?
#
# Naive Bayes is built on:
#
# Probability
#
# Bayes’ Theorem
#
# Likelihoods & priors
#
# It does not:
#
# Learn weights via gradient descent
#
# Optimize a loss function like logistic regression
#
# Instead, it:
#
# Computes probabilities directly and compares them

# %%
# 1️⃣ Imports
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 2️⃣ Simple dataset
texts = [
    "free money now",
    "limited offer buy now",
    "hello how are you",
    "let us meet tomorrow",
    "win cash prize",
    "are you available today"
]
labels = [1, 1, 0, 0, 1, 0]  # 1 = Spam, 0 = Not Spam

# 3️⃣ Text → numbers
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)

# 4️⃣ Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, labels, test_size=0.3, random_state=42
)

# 5️⃣ Model
model = MultinomialNB()
model.fit(X_train, y_train)

# 6️⃣ Predictions
y_pred = model.predict(X_test)

# 7️⃣ Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5
