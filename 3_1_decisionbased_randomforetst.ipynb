# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/3_1_decisionbased_randomforetst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# “A single decision tree is unstable; Random Forest reduces overfitting by averaging multiple trees trained on random data.”

# %% [markdown]
# 🌲 Random Forest Regression
#
# 🧠 1️⃣ WHY Random Forest Regression EXISTS
#
# You already know this:
#
# Decision Tree learns rules very well
#
# But one tree:
#
# Memorizes data
#
# Changes a lot if data changes
#
# Overfits easily
#
# So ML people asked:
#
# “What if we train MANY trees and let them vote?”
#
# That question created Random Forest.

# %%
# ==================================
# Random Forest Regression (One Cell)
# ==================================

# 1. Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 2. Create dataset
data = {
    "Experience": [1, 2, 3, 4, 5, 6, 7, 8],
    "Salary": [3, 5, 9, 15, 23, 35, 50, 70]
}

df = pd.DataFrame(data)
print("Dataset:")
print(df)

# 3. Feature & target
X = df[["Experience"]]
y = df["Salary"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# 5. Train Random Forest
model = RandomForestRegressor(
    n_estimators=100,
    max_depth=4,
    random_state=42
)
model.fit(X_train, y_train)

# 6. Predict
y_pred = model.predict(X_test)

# 7. Evaluate
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R2  :", r2)

# 8. Feature importance
print("\nFeature Importance:")
print(model.feature_importances_)
# Out:
# Dataset:
#    Experience  Salary
# 0           1       3
# 1           2       5
# 2           3       9
# 3           4      15
# 4           5      23
# 5           6      35
# 6           7      50
# 7           8      70
#
# Model Evaluation:
# MAE : 2.4499999999999993
# MSE : 8.824899999999996
# RMSE: 2.9706733243492116
# R2  : 0.9607782222222222
#
# Feature Importance:
# [1.]
