# %% [markdown]
# <a href="https://colab.research.google.com/github/NavjyotDataScientist/kaggle_huggingface_universe_projects/blob/main/8_0_marginbased_support_vector_machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SVM tries to separate classes with the widest possible gap (margin).

# %%
# 1️⃣ Imports
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 2️⃣ Dataset
X, y = make_classification(
    n_samples=100,
    n_features=2,
    n_classes=2,
    n_redundant=0,
    random_state=42
)

# 3️⃣ Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 4️⃣ Model
model = SVC(kernel="linear", C=1)
model.fit(X_train, y_train)

# 5️⃣ Prediction
y_pred = model.predict(X_test)

# 6️⃣ Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
